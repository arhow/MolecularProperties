# %%
# %%HTML
# <style>
#    div#notebook-container    { width: 95%; }
#    div#menubar-container     { width: 65%; }
#    div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#    div#notebook-container    { width: 95%; }
#    div#menubar-container     { width: 65%; }
#    div#maintoolbar-container { width: 99%; }
# </style>

# %%
import sys
sys.path.append("../..") # Adds higher directory to python modules path.
from utilities import aggregate_feature_calculators
from utilities import aggregate_feature_calculators_setting as aggcal
from utilities.parallel import Parallel
from utilities.dfdb import DFDB

from utilities.process.pqueue import *
from utilities.process.pnode import *
from utilities.process.putilities import *

# %%
import numpy as np
import pandas as pd
import os
import time
import datetime
import json
import copy
import gc
import warnings
from tqdm import tqdm_notebook, tqdm

import optuna

import lightgbm as lgb
import xgboost as xgb

from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold,TimeSeriesSplit, GroupKFold
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
from sklearn import preprocessing

import eli5
from eli5.sklearn import PermutationImportance

import networkx as nx

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_file_folder =  '../../data/input'
os.listdir(csv_file_folder)
# Out:
# ['structures',
#  'magnetic_shielding_parameters.csv',
#  'train.csv',
#  'dipole_moments.csv',
#  'magnetic_shielding_tensors.csv',
#  'mulliken_charges.csv',
#  'potential_energy.csv',
#  'sample_submission.csv',
#  'scalar_coupling_contributions.csv',
#  'structures.csv',
#  'test.csv']

# %%
file_folder =  '../../data/feature'
[f for f in os.listdir(file_folder) if (f.endswith('.pkl')) and (not f.startswith('.'))]
# Out:
# ['angles-and-distances_test.pkl',
#  'angles-and-distances_train.pkl',
#  'brute-force-feature-engineering_test.pkl',
#  'eem_test.pkl',
#  'giba-r-data-table-simple-features-0-991-lb_test.pkl',
#  'giba-r-data-table-simple-features-0-991-lb_train.pkl',
#  'brute-force-feature-engineering_train.pkl',
#  'keras-neural-net-for-champs_test.pkl',
#  'keras-neural-net-for-champs_train.pkl',
#  'eem_train.pkl',
#  'molecular-properties-eda-and-models_test.pkl',
#  'molecular-properties-eda-and-models_train.pkl',
#  'molecule-with-openbabel_test.pkl',
#  'molecule-with-openbabel_train.pkl',
#  'dataset-with-number-of-bonds-between-atoms_test.pkl',
#  'brute-force-feature-engineering-mini_test.pkl',
#  'eachtype_train.pkl',
#  'eachtype_test.pkl',
#  'giba-r-data-table-simple-features-1-17-lb_test.pkl',
#  'dataset-with-number-of-bonds-between-atoms_train.pkl',
#  'brute-force-feature-engineering-mini_train.pkl',
#  'giba-r-data-table-simple-features-1-17-lb_train.pkl',
#  'bonds-from-structure-data_train.pkl',
#  'coulomb-interaction-speed-up_test.pkl',
#  'bonds-from-structure-data_test.pkl',
#  'coulomb-interaction-speed-up_train.pkl']

# %%
file_list = ['giba-r-data-table-simple-features-1-17-lb_train.pkl',
 'eem_train.pkl',
 'coulomb-interaction-speed-up_train.pkl',
 'dataset-with-number-of-bonds-between-atoms_test.pkl',
 'keras-neural-net-for-champs_train.pkl',
 'angles-and-distances_test.pkl',
 'keras-neural-net-for-champs_test.pkl',
 'brute-force-feature-engineering-mini_train.pkl',
 'dataset-with-number-of-bonds-between-atoms_train.pkl',
 'coulomb-interaction-speed-up_test.pkl',
 'bonds-from-structure-data_train.pkl',
 'eem_test.pkl',
 'molecule-with-openbabel_train.pkl',
 'molecular-properties-eda-and-models_train.pkl',
 'brute-force-feature-engineering-mini_test.pkl',
 'molecular-properties-eda-and-models_test.pkl',
 'bonds-from-structure-data_test.pkl',
 'molecule-with-openbabel_test.pkl',
 'giba-r-data-table-simple-features-1-17-lb_test.pkl',
 'angles-and-distances_train.pkl']
print(len(file_list))
# Out:
# 20

# %%
trail = []
def prepare_data(feature_folder='../../data/feature', csv_file_folder='../../data/input', feature_file_list=None, trail=trail):
    
    if os.path.exists(f'{feature_folder}/df_train'):
        print(f'=========================load from temp===============================')
        df_train = pd.read_pickle(f'{feature_folder}/df_train')
        df_test = pd.read_pickle(f'{feature_folder}/df_test')
        return df_train, df_test
    
    df_train = pd.read_csv(f"{csv_file_folder}/train.csv")
    df_test = pd.read_csv(f"{csv_file_folder}/test.csv")
    scalar_coupling_contributions = pd.read_csv(f'{csv_file_folder}/scalar_coupling_contributions.csv')
    
    #scalar_coupling_constant fc sd pso dso
    df_train = pd.merge(df_train, scalar_coupling_contributions, how = 'left',
                  left_on  = ['molecule_name', 'atom_index_0', 'atom_index_1', 'type'],
                  right_on = ['molecule_name', 'atom_index_0', 'atom_index_1', 'type'])
    
    print(df_train.shape, df_test.shape)

    if type(feature_file_list) == type(None):
        feature_file_list = os.listdir(feature_folder)

    for f in feature_file_list:
        print(f'========================={f}===============================')
        if (f.endswith('.pkl')) and (not f.startswith('.')):
            if f[:-4].endswith('train'):
                df_feature_i = pd.read_pickle(f'{feature_folder}/{f}').sort_values(by=['id'])
                df_feature_i = df_feature_i.reset_index(drop=True)
                columns_i = df_feature_i.columns.tolist()
                new_columns = set(columns_i) - set(df_train.columns.tolist())
                duplicates_columns = [col for col in columns_i if col not in list(new_columns)]
                for col in duplicates_columns:
                    try:
                        error = np.where(df_feature_i[col].values!=df_train[col].values)[0]
                        if error.shape[0] > 0:
                            if np.where(~np.isnan(df_feature_i[col].values[np.where(df_feature_i[col].values!=df_train[col].values)[0]]))[0].shape[0]>0:
                                if not str in [type(df_train[col].values[0]),type(df_feature_i[col].values[0])]:
                                    trail.append({'df_feature_i':df_feature_i, 'df_train':df_train})
                                    print(col, error, [f'{v1}:{v2}' for v1, v2 in zip(df_feature_i[col].values[error], df_train[col].values[error])])
                                    raise Exception()
                    except Exception as e:
#                         raise Exception(col)
                        print(col)
                df_train = pd.merge(df_train, df_feature_i[list(new_columns) + ['id']], on='id')
                df_train = df_train.sort_values(by=['id'])
                df_train = df_train.reset_index(drop=True)
                print('train add', f, new_columns)
            if f[:-4].endswith('test'):
                df_feature_i = pd.read_pickle(f'{feature_folder}/{f}').sort_values(by=['id'])
                df_feature_i = df_feature_i.reset_index(drop=True)
                columns_i = df_feature_i.columns.tolist()
                new_columns = set(columns_i) - set(df_test.columns.tolist())
                duplicates_columns = [col for col in columns_i if col not in list(new_columns)]
                for col in duplicates_columns:
                    try:
                        error = np.where(df_feature_i[col].values!=df_test[col].values)[0]
                        if error.shape[0] > 0:
                            if np.where(~np.isnan(df_feature_i[col].values[np.where(df_feature_i[col].values!=df_test[col].values)[0]]))[0].shape[0]>0:
                                if not str in [type(df_test[col].values[0]),type(df_feature_i[col].values[0])]:
                                    trail.append({'df_feature_i':df_feature_i, 'df_test':df_test})
                                    print(col, error, [f'{v1}:{v2}' for v1, v2 in zip(df_feature_i[col].values[error], df_test[col].values[error])])
                                    raise Exception()
                    except Exception as e:
#                         raise Exception(col)
                        print(col)
                df_test = pd.merge(df_test, df_feature_i[list(new_columns) + ['id']], on='id')
                df_test = df_test.sort_values(by=['id'])
                df_test = df_test.reset_index(drop=True)
                print('test add', f, new_columns)

    print(f'=========================encode label===============================')
    numerics = ['int16', 'int8', 'int32', 'int64', 'float16', 'float32', 'float64']
    for col in df_train.columns:
        col_type = df_train[col].dtypes
        if not col_type in numerics:
            print(col, df_train[col].unique())
            le = LabelEncoder()
            le.fit(list(df_train[col].values) + list(df_test[col].values))
            df_train[col] = le.transform(list(df_train[col].values))
            df_test[col] = le.transform(list(df_test[col].values))
            print(le.classes_)

    print(f'=========================fill nan inf===============================')
    df_train = df_train.replace([np.inf, -np.inf], np.nan)
    df_train = df_train.fillna(0)
    df_test = df_test.replace([np.inf, -np.inf], np.nan)
    df_test = df_test.fillna(0)

    print(f'=========================rename===============================')
    df_train = df_train.rename(columns={'id': 'index'}) #'scalar_coupling_constant': 'y'
    df_test = df_test.rename(columns={'id': 'index'})
    df_train = df_train.rename(columns={'molecule_name':'group'})
    df_test = df_test.rename(columns={'molecule_name':'group'})
    df_test = df_test.rename(columns={'cycle_size_mean_x':'atom_index_0_cycle_size_mean', 
                            'cycle_size_mean_y':'atom_index_1_cycle_size_mean',
                           'n_cycle_x':'atom_index_0_n_cycle',
                           'n_cycle_y':'atom_index_1_n_cycle'})

    df_train = df_train.reset_index(drop=True)
    df_test = df_test.reset_index(drop=True)
    
    if not os.path.exists(f'{feature_folder}/df_train'):
        print(f'=========================save tmp===============================')
        df_train.to_pickle(f'{file_folder}/df_train.gzde', compression='gzip')
        df_test.to_pickle(f'{file_folder}/df_test.gzde', compression='gzip')
    return df_train, df_test

# %%
df_train, df_test = prepare_data(feature_file_list=file_list)
# Out:
# (4658147, 10) (2505542, 5)
# =========================giba-r-data-table-simple-features-1-17-lb_train.pkl===============================
# train add giba-r-data-table-simple-features-1-17-lb_train.pkl {'NH', 'inv_dist1E', 'linkM1', 'ID', 'adN2', 'yukawa_H.y', 'coulomb_H.x', 'distN0', 'inv_dist1R', 'distC0', 'yukawa_C.y', 'atom_index_1.1', 'structure_z_1', 'E0', 'structure_x_0', 'coulomb_N.y', 'vander_O.y', 'adC4', 'structure_y_1', 'structure_z_0', 'typei', 'coulomb_C.x', 'yukawa_O.x', 'inv_distP', 'vander_H.x', 'structure_atom_0', 'sd_molecule_atom_1_dist_xyz', 'E1', 'vander_N.y', 'linkN', 'structure_x_1', 'structure_atom_1', 'coulomb_F.y', 'inv_dist1', 'inv_dist0R', 'link0', 'inv_dist0', 'inv_distPR', 'mean_molecule_atom_0_dist_xyz', 'distH0', 'pos', 'linkM0', 'yukawa_N.x', 'structure_y_0', 'adH2', 'yukawa_H.x', 'vander_C.x', 'vander_F.x', 'adH3', 'R0', 'sd_molecule_atom_0_dist_xyz', 'coulomb_O.x', 'coulomb_O.y', 'NN', 'N2', 'vander_N.x', 'NF', 'yukawa_C.x', 'adC1', 'inv_dist0E', 'yukawa_N.y', 'adH4', 'adN4', 'max_molecule_atom_0_dist_xyz', 'adC3', 'adN1', 'max_molecule_atom_1_dist_xyz', 'link1', 'vander_F.y', 'vander_C.y', 'yukawa_F.y', 'adC2', 'NC', 'coulomb_F.x', 'coulomb_H.y', 'molecule_name.1', 'distN1', 'distC1', 'adH1', 'yukawa_F.x', 'mean_molecule_atom_1_dist_xyz', 'N1', 'R1', 'vander_O.x', 'coulomb_N.x', 'dist_xyz', 'min_molecule_atom_1_dist_xyz', 'adN3', 'yukawa_O.y', 'vander_H.y', 'inv_distPE', 'min_molecule_atom_0_dist_xyz', 'coulomb_C.y', 'NO', 'distH1'}
# =========================eem_train.pkl===============================
# train add eem_train.pkl {'eem_0', 'eem_1'}
# =========================coulomb-interaction-speed-up_train.pkl===============================
# train add coulomb-interaction-speed-up_train.pkl {'dist_C_2_y', 'dist_H_2_y', 'dist_C_2_x', 'dist_C_3_x', 'dist_O_2_y', 'dist_H_1_x', 'dist_F_0_y', 'dist_O_3_x', 'dist_H_2_x', 'dist_O_1_y', 'dist_O_0_x', 'dist_F_4_y', 'dist_H_3_x', 'dist_C_4_x', 'dist_N_1_x', 'dist_C_1_y', 'dist_N_4_x', 'dist_F_2_x', 'dist_C_4_y', 'dist_N_3_x', 'dist_N_4_y', 'dist_H_4_y', 'dist_F_1_x', 'dist_C_0_x', 'dist_H_4_x', 'dist_F_4_x', 'dist_N_1_y', 'dist_O_1_x', 'dist_F_0_x', 'dist_C_0_y', 'dist_C_3_y', 'dist_F_2_y', 'dist_N_0_y', 'dist_N_0_x', 'dist_H_0_y', 'dist_N_2_x', 'dist_F_3_x', 'dist_O_4_y', 'dist_H_0_x', 'dist_N_3_y', 'dist_H_3_y', 'dist_O_3_y', 'dist_O_4_x', 'dist_H_1_y', 'dist_F_1_y', 'dist_N_2_y', 'dist_O_0_y', 'dist_F_3_y', 'dist_C_1_x', 'dist_O_2_x'}
# =========================dataset-with-number-of-bonds-between-atoms_test.pkl===============================
# test add dataset-with-number-of-bonds-between-atoms_test.pkl {'n_cycle_x', 'n_cycle_y', 'nbond', 'error', 'atom_index_0_charge', 'atom_index_1_charge', 'cycle_size_mean_x', 'L2dist', 'bond_type', 'cycle_size_mean_y', 'is_found_bond'}
# =========================keras-neural-net-for-champs_train.pkl===============================
# train add keras-neural-net-for-champs_train.pkl {'y_closest_0', 'atom_1', 'x_closest_1', 'atom_index_farthest_1', 'max_distance_y', 'distance_center0', 'cos_center0', 'y_1', 'x_closest_0', 'distance_farthest_0', 'cos_c1', 'z_1', 'x_farthest_0', 'distance_c1', 'cos_center1', 'distance_center1', 'c_x', 'atom_0', 'distance_c0', 'y_closest_1', 'distance', 'distance_closest_0', 'max_distance_x', 'min_distance_x', 'distance_closest_1', 'distance_f0', 'atom_index_closest_1', 'z_closest_1', 'z_0', 'atom_index_closest_0', 'cos_f0', 'c_y', 'x_1', 'dz', 'z_farthest_1', 'distance_f1', 'cos_f0_f1', 'dx', 'cos_c0', 'cos_center0_center1', 'y_farthest_1', 'dy', 'y_0', 'y_farthest_0', 'c_z', 'z_farthest_0', 'atom_index_farthest_0', 'atom_n', 'distance_farthest_1', 'x_farthest_1', 'cos_c0_c1', 'cos_f1', 'min_distance_y', 'x_0', 'z_closest_0'}
# =========================angles-and-distances_test.pkl===============================
# test add angles-and-distances_test.pkl {'tertiary_angle_21', 'tertiary_atom_7', 'tertiary_distance_13', 'tertiary_angle_3', 'tertiary_distance_4', 'tertiary_angle_18', 'tertiary_angle_17', 'tertiary_angle_8', 'tertiary_angle_14', 'tertiary_distance_1', 'tertiary_distance_17', 'tertiary_angle_7', 'tertiary_angle_11', 'tertiary_distance_9', 'tertiary_distance_25', 'tertiary_angle_24', 'tertiary_atom_3', 'tertiary_atom_18', 'tertiary_distance_0', 'tertiary_angle_16', 'tertiary_atom_1', 'tertiary_angle_20', 'tertiary_angle_13', 'tertiary_distance_16', 'tertiary_distance_21', 'tertiary_atom_23', 'tertiary_distance_20', 'tertiary_atom_4', 'bond_atom', 'tertiary_angle_9', 'tertiary_atom_9', 'tertiary_angle_0', 'tertiary_distance_7', 'tertiary_atom_2', 'tertiary_atom_15', 'tertiary_atom_11', 'tertiary_atom_13', 'tertiary_angle_12', 'tertiary_atom_20', 'tertiary_distance_19', 'tertiary_angle_25', 'tertiary_distance_24', 'tertiary_angle_2', 'tertiary_distance_5', 'tertiary_atom_0', 'tertiary_distance_11', 'tertiary_atom_10', 'tertiary_atom_17', 'tertiary_distance_6', 'bond_distance', 'tertiary_distance_3', 'tertiary_angle_19', 'tertiary_distance_18', 'tertiary_distance_8', 'tertiary_distance_14', 'tertiary_atom_5', 'tertiary_atom_8', 'tertiary_atom_19', 'tertiary_distance_15', 'tertiary_distance_2', 'tertiary_angle_26', 'tertiary_atom_24', 'tertiary_angle_5', 'tertiary_distance_23', 'tertiary_atom_16', 'tertiary_atom_22', 'tertiary_angle_6', 'tertiary_angle_15', 'tertiary_atom_6', 'tertiary_atom_26', 'tertiary_angle_1', 'tertiary_angle_10', 'tertiary_angle_23', 'tertiary_distance_12', 'tertiary_distance_26', 'tertiary_angle_22', 'tertiary_atom_14', 'tertiary_atom_12', 'tertiary_distance_22', 'totalatoms', 'tertiary_atom_25', 'tertiary_distance_10', 'tertiary_atom_21', 'tertiary_angle_4'}
# =========================keras-neural-net-for-champs_test.pkl===============================
# test add keras-neural-net-for-champs_test.pkl {'y_closest_0', 'atom_1', 'x_closest_1', 'atom_index_farthest_1', 'max_distance_y', 'distance_center0', 'cos_center0', 'y_1', 'x_closest_0', 'distance_farthest_0', 'cos_c1', 'z_1', 'x_farthest_0', 'distance_c1', 'cos_center1', 'distance_center1', 'c_x', 'atom_0', 'distance_c0', 'y_closest_1', 'distance', 'distance_closest_0', 'max_distance_x', 'min_distance_x', 'distance_closest_1', 'distance_f0', 'atom_index_closest_1', 'z_closest_1', 'z_0', 'atom_index_closest_0', 'cos_f0', 'c_y', 'x_1', 'dz', 'z_farthest_1', 'distance_f1', 'cos_f0_f1', 'dx', 'cos_c0', 'cos_center0_center1', 'y_farthest_1', 'dy', 'y_0', 'y_farthest_0', 'c_z', 'z_farthest_0', 'atom_index_farthest_0', 'atom_n', 'distance_farthest_1', 'x_farthest_1', 'cos_c0_c1', 'cos_f1', 'min_distance_y', 'x_0', 'z_closest_0'}
# =========================brute-force-feature-engineering-mini_train.pkl===============================
# train add brute-force-feature-engineering-mini_train.pkl {'molecule_atom_1_dist_min_diff', 'molecule_atom_index_1_dist_max_diff', 'molecule_atom_index_0_dist_std_div', 'molecule_atom_index_1_dist_mean_diff', 'molecule_atom_index_0_y_1_mean_div', 'molecule_atom_index_0_dist_std', 'molecule_type_dist_mean_diff', 'molecule_atom_index_1_dist_std', 'atom_1_couples_count', 'molecule_atom_index_0_dist_max', 'molecule_atom_index_0_dist_mean', 'dist', 'molecule_atom_index_0_dist_mean_div', 'molecule_atom_index_0_y_1_mean_diff', 'molecule_atom_index_1_dist_mean_div', 'molecule_type_dist_mean_div', 'molecule_atom_index_0_dist_mean_diff', 'molecule_type_dist_std_diff', 'molecule_dist_max', 'atom_0_couples_count', 'molecule_type_dist_min', 'molecule_atom_index_1_dist_std_diff', 'molecule_atom_index_0_dist_max_div', 'molecule_atom_1_dist_std_diff', 'molecule_atom_index_1_dist_std_div', 'molecule_atom_index_0_dist_min_diff', 'molecule_atom_index_1_dist_min', 'molecule_atom_1_dist_mean', 'molecule_atom_index_1_dist_mean', 'molecule_atom_index_0_y_1_std', 'molecule_couples', 'molecule_atom_index_1_dist_min_diff', 'molecule_atom_index_1_dist_min_div', 'molecule_atom_index_1_dist_max_div', 'molecule_type_dist_max', 'molecule_atom_index_1_dist_max', 'molecule_atom_index_0_dist_min_div', 'molecule_atom_index_0_dist_max_diff', 'molecule_atom_1_dist_min_div', 'molecule_atom_index_0_z_1_std', 'molecule_dist_min', 'molecule_atom_index_0_y_1_max_diff', 'molecule_atom_index_0_dist_std_diff', 'molecule_atom_index_0_x_1_std', 'molecule_dist_mean', 'molecule_type_0_dist_std_diff', 'molecule_atom_index_0_dist_min'}
# =========================dataset-with-number-of-bonds-between-atoms_train.pkl===============================
# train add dataset-with-number-of-bonds-between-atoms_train.pkl {'nbond', 'error', 'atom_index_0_charge', 'atom_index_0_n_cycle', 'atom_index_1_charge', 'atom_index_0_cycle_size_mean', 'L2dist', 'bond_type', 'atom_index_1_n_cycle', 'atom_index_1_cycle_size_mean', 'is_found_bond'}
# =========================coulomb-interaction-speed-up_test.pkl===============================
# test add coulomb-interaction-speed-up_test.pkl {'dist_C_2_y', 'dist_H_2_y', 'dist_C_2_x', 'dist_C_3_x', 'dist_O_2_y', 'dist_H_1_x', 'dist_F_0_y', 'dist_O_3_x', 'dist_H_2_x', 'dist_O_1_y', 'dist_O_0_x', 'dist_F_4_y', 'dist_H_3_x', 'dist_C_4_x', 'dist_N_1_x', 'dist_C_1_y', 'dist_N_4_x', 'dist_F_2_x', 'dist_C_4_y', 'dist_N_3_x', 'dist_N_4_y', 'dist_H_4_y', 'dist_F_1_x', 'dist_C_0_x', 'dist_H_4_x', 'dist_F_4_x', 'dist_N_1_y', 'dist_O_1_x', 'dist_F_0_x', 'dist_C_0_y', 'dist_C_3_y', 'dist_F_2_y', 'dist_N_0_y', 'dist_N_0_x', 'dist_H_0_y', 'dist_N_2_x', 'dist_F_3_x', 'dist_O_4_y', 'dist_H_0_x', 'dist_N_3_y', 'dist_H_3_y', 'dist_O_3_y', 'dist_O_4_x', 'dist_H_1_y', 'dist_F_1_y', 'dist_N_2_y', 'dist_O_0_y', 'dist_F_3_y', 'dist_C_1_x', 'dist_O_2_x'}
# =========================bonds-from-structure-data_train.pkl===============================
# train add bonds-from-structure-data_train.pkl {'atom_0_atomic_radius', 'atom_0_bond_lengths_max', 'atom_1_rad', 'atom_0_electronegativity', 'atom_0_bond_lengths_std', 'atom_1_bond_lengths_mean', 'atom_0_atomic_mass', 'atom_0_bond_lengths_min', 'atom_0_covalenzradius', 'atom_0_EN', 'atom_1_bond_lengths_max', 'atom_0_rad', 'atom_0_ionization_energy', 'atom_1_bond_lengths_min', 'atom_1_atomic_mass', 'atom_1_n_bonds', 'atom_1_atomic_radius', 'atom_1_bond_lengths_std', 'atom_1_ionization_energy', 'atom_1_atomic_number', 'atom_1_vanderwaalsradius', 'atom_1_covalenzradius', 'atom_1_dihedral', 'atom_0_n_bonds', 'atom_0_bond_lengths_mean', 'atom_0_dihedral', 'atom_1_EN', 'atom_0_atomic_number', 'atom_1_electronegativity', 'atom_0_vanderwaalsradius'}
# =========================eem_test.pkl===============================
# test add eem_test.pkl {'eem_0', 'eem_1'}
# =========================molecule-with-openbabel_train.pkl===============================
# train add molecule-with-openbabel_train.pkl {'molecule_atom_1_dist_min', 'abs_dist_xy', 'molecule_atom_index_0_y_1_max', 'O', 'abs_dist_yz', 'dist_xy', 'H', 'abs_dist', 'dist_yz', 'C', 'dist_to_type_std', 'dist_to_type_mean_xz', 'molecule_bonds_dist_std', 'bonds', 'dist_to_type_mean_xy', 'molecule_bonds_dist_std_diff', 'dist_xz', 'molecule_type_dist_std', 'F', 'molecule_type_dist_mean', 'abs_dist_xz', 'N', 'dist_to_type_mean', 'dist_to_type_mean_yz', 'molecule_atom_1_dist_std', 'molecule_atom_index_0_y_1_mean'}
# =========================molecular-properties-eda-and-models_train.pkl===============================
# train add molecular-properties-eda-and-models_train.pkl {'dist_z', 'dist_to_type_0_mean', 'dist_y', 'dist_to_type_1_mean', 'type_1', 'type_0', 'dist_x'}
# =========================brute-force-feature-engineering-mini_test.pkl===============================
# test add brute-force-feature-engineering-mini_test.pkl {'molecule_atom_1_dist_min_diff', 'molecule_atom_index_1_dist_max_diff', 'molecule_atom_index_0_dist_std_div', 'molecule_atom_index_1_dist_mean_diff', 'molecule_atom_index_0_y_1_mean_div', 'molecule_atom_index_0_dist_std', 'molecule_type_dist_mean_diff', 'molecule_atom_index_1_dist_std', 'atom_1_couples_count', 'molecule_atom_index_0_dist_max', 'molecule_atom_index_0_dist_mean', 'dist', 'molecule_atom_index_0_dist_mean_div', 'molecule_atom_index_0_y_1_mean_diff', 'molecule_atom_index_1_dist_mean_div', 'molecule_type_dist_mean_div', 'molecule_atom_index_0_dist_mean_diff', 'molecule_type_dist_std_diff', 'molecule_dist_max', 'atom_0_couples_count', 'molecule_type_dist_min', 'molecule_atom_index_1_dist_std_diff', 'molecule_atom_index_0_dist_max_div', 'molecule_atom_1_dist_std_diff', 'molecule_atom_index_1_dist_std_div', 'molecule_atom_index_0_dist_min_diff', 'molecule_atom_index_1_dist_min', 'molecule_atom_1_dist_mean', 'molecule_atom_index_1_dist_mean', 'molecule_atom_index_0_y_1_std', 'molecule_couples', 'molecule_atom_index_1_dist_min_diff', 'molecule_atom_index_1_dist_min_div', 'molecule_atom_index_1_dist_max_div', 'molecule_type_dist_max', 'molecule_atom_index_1_dist_max', 'molecule_atom_index_0_dist_min_div', 'molecule_atom_index_0_dist_max_diff', 'molecule_atom_1_dist_min_div', 'molecule_atom_index_0_z_1_std', 'molecule_dist_min', 'molecule_atom_index_0_y_1_max_diff', 'molecule_atom_index_0_dist_std_diff', 'molecule_atom_index_0_x_1_std', 'molecule_dist_mean', 'molecule_type_0_dist_std_diff', 'molecule_atom_index_0_dist_min'}
# =========================molecular-properties-eda-and-models_test.pkl===============================
# test add molecular-properties-eda-and-models_test.pkl {'dist_z', 'dist_to_type_0_mean', 'dist_to_type_mean', 'dist_y', 'dist_to_type_1_mean', 'type_1', 'type_0', 'dist_x', 'molecule_type_dist_mean'}
# =========================bonds-from-structure-data_test.pkl===============================
# test add bonds-from-structure-data_test.pkl {'atom_0_atomic_radius', 'atom_0_bond_lengths_max', 'atom_1_rad', 'atom_0_electronegativity', 'atom_0_bond_lengths_std', 'atom_1_bond_lengths_mean', 'atom_0_atomic_mass', 'atom_0_bond_lengths_min', 'atom_0_covalenzradius', 'atom_0_EN', 'atom_1_bond_lengths_max', 'atom_0_rad', 'atom_0_ionization_energy', 'atom_1_bond_lengths_min', 'atom_1_atomic_mass', 'atom_1_n_bonds', 'atom_1_atomic_radius', 'atom_1_bond_lengths_std', 'atom_1_ionization_energy', 'atom_1_atomic_number', 'atom_1_vanderwaalsradius', 'atom_1_covalenzradius', 'atom_1_dihedral', 'atom_0_n_bonds', 'atom_0_bond_lengths_mean', 'atom_0_dihedral', 'atom_1_EN', 'atom_0_atomic_number', 'atom_1_electronegativity', 'atom_0_vanderwaalsradius'}
# =========================molecule-with-openbabel_test.pkl===============================
# test add molecule-with-openbabel_test.pkl {'molecule_atom_1_dist_min', 'abs_dist_xy', 'molecule_atom_index_0_y_1_max', 'O', 'abs_dist_yz', 'dist_xy', 'H', 'abs_dist', 'dist_yz', 'C', 'dist_to_type_std', 'dist_to_type_mean_xz', 'molecule_bonds_dist_std', 'bonds', 'dist_to_type_mean_xy', 'molecule_bonds_dist_std_diff', 'dist_xz', 'molecule_type_dist_std', 'F', 'abs_dist_xz', 'N', 'dist_to_type_mean_yz', 'molecule_atom_1_dist_std', 'molecule_atom_index_0_y_1_mean'}
# =========================giba-r-data-table-simple-features-1-17-lb_test.pkl===============================
# test add giba-r-data-table-simple-features-1-17-lb_test.pkl {'NH', 'linkM1', 'ID', 'distN0', 'inv_dist1R', 'yukawa_C.y', 'atom_index_1.1', 'structure_z_1', 'E0', 'vander_O.y', 'structure_z_0', 'coulomb_C.x', 'inv_distP', 'vander_H.x', 'E1', 'vander_N.y', 'structure_x_1', 'coulomb_F.y', 'inv_dist1', 'link0', 'inv_dist0', 'mean_molecule_atom_0_dist_xyz', 'linkM0', 'yukawa_N.x', 'adH2', 'yukawa_H.x', 'vander_C.x', 'sd_molecule_atom_0_dist_xyz', 'coulomb_O.y', 'NN', 'N2', 'inv_dist0E', 'yukawa_N.y', 'adN4', 'adN1', 'vander_C.y', 'yukawa_F.y', 'adC2', 'NC', 'coulomb_F.x', 'molecule_name.1', 'distN1', 'distC1', 'R1', 'coulomb_N.x', 'min_molecule_atom_1_dist_xyz', 'adN3', 'inv_distPE', 'coulomb_C.y', 'inv_dist1E', 'adN2', 'yukawa_H.y', 'coulomb_H.x', 'distC0', 'structure_x_0', 'coulomb_N.y', 'adC4', 'structure_y_1', 'typei', 'yukawa_O.x', 'structure_atom_0', 'sd_molecule_atom_1_dist_xyz', 'linkN', 'structure_atom_1', 'inv_dist0R', 'inv_distPR', 'distH0', 'pos', 'structure_y_0', 'vander_F.x', 'adH3', 'R0', 'coulomb_O.x', 'vander_N.x', 'NF', 'yukawa_C.x', 'adC1', 'adH4', 'max_molecule_atom_0_dist_xyz', 'adC3', 'max_molecule_atom_1_dist_xyz', 'link1', 'vander_F.y', 'coulomb_H.y', 'adH1', 'yukawa_F.x', 'mean_molecule_atom_1_dist_xyz', 'N1', 'vander_O.x', 'dist_xyz', 'yukawa_O.y', 'vander_H.y', 'min_molecule_atom_0_dist_xyz', 'NO', 'distH1'}
# =========================angles-and-distances_train.pkl===============================
# train add angles-and-distances_train.pkl {'tertiary_angle_21', 'tertiary_atom_17', 'tertiary_atom_7', 'tertiary_distance_6', 'tertiary_distance_13', 'bond_distance', 'tertiary_angle_3', 'tertiary_distance_4', 'tertiary_distance_3', 'tertiary_angle_19', 'tertiary_distance_18', 'tertiary_distance_8', 'tertiary_distance_14', 'tertiary_atom_5', 'tertiary_atom_8', 'tertiary_angle_18', 'tertiary_angle_17', 'tertiary_atom_19', 'tertiary_distance_15', 'tertiary_angle_8', 'tertiary_angle_14', 'tertiary_distance_1', 'tertiary_distance_2', 'tertiary_distance_17', 'tertiary_angle_7', 'tertiary_angle_11', 'tertiary_atom_24', 'tertiary_distance_9', 'tertiary_distance_25', 'tertiary_angle_26', 'tertiary_angle_24', 'tertiary_atom_3', 'tertiary_angle_5', 'tertiary_atom_18', 'tertiary_distance_0', 'tertiary_angle_16', 'tertiary_atom_1', 'tertiary_angle_20', 'tertiary_angle_4', 'tertiary_distance_23', 'tertiary_atom_16', 'tertiary_angle_13', 'tertiary_distance_16', 'tertiary_distance_21', 'tertiary_angle_6', 'tertiary_atom_22', 'tertiary_atom_23', 'tertiary_distance_20', 'tertiary_atom_4', 'tertiary_angle_15', 'tertiary_atom_6', 'bond_atom', 'tertiary_angle_9', 'tertiary_atom_9', 'tertiary_angle_1', 'tertiary_angle_0', 'tertiary_atom_26', 'tertiary_angle_23', 'tertiary_distance_7', 'tertiary_angle_10', 'tertiary_distance_12', 'tertiary_distance_26', 'tertiary_atom_2', 'tertiary_angle_22', 'tertiary_atom_15', 'tertiary_atom_14', 'tertiary_atom_12', 'tertiary_atom_11', 'tertiary_atom_13', 'tertiary_atom_25', 'tertiary_angle_12', 'tertiary_distance_22', 'totalatoms', 'tertiary_distance_10', 'tertiary_atom_20', 'tertiary_distance_19', 'tertiary_angle_25', 'tertiary_atom_21', 'tertiary_atom_10', 'tertiary_distance_24', 'tertiary_angle_2', 'tertiary_distance_5', 'tertiary_atom_0', 'tertiary_distance_11'}
# =========================encode label===============================
# molecule_name ['dsgdb9nsd_000001' 'dsgdb9nsd_000002' 'dsgdb9nsd_000003' ...
#  'dsgdb9nsd_133881' 'dsgdb9nsd_133882' 'dsgdb9nsd_133884']
# ['dsgdb9nsd_000001' 'dsgdb9nsd_000002' 'dsgdb9nsd_000003' ...
#  'dsgdb9nsd_133883' 'dsgdb9nsd_133884' 'dsgdb9nsd_133885']
# type ['1JHC' '2JHH' '1JHN' '2JHN' '2JHC' '3JHH' '3JHC' '3JHN']
# ['1JHC' '1JHN' '2JHC' '2JHH' '2JHN' '3JHC' '3JHH' '3JHN']
# structure_atom_0 ['H']
# ['H']
# structure_atom_1 ['C' 'H' 'N']
# ['C' 'H' 'N']
# molecule_name.1 ['dsgdb9nsd_000001' 'dsgdb9nsd_000002' 'dsgdb9nsd_000003' ...
#  'dsgdb9nsd_133881' 'dsgdb9nsd_133882' 'dsgdb9nsd_133884']
# ['dsgdb9nsd_000001' 'dsgdb9nsd_000002' 'dsgdb9nsd_000003' ...
#  'dsgdb9nsd_133883' 'dsgdb9nsd_133884' 'dsgdb9nsd_133885']
# atom_1 ['C' 'H' 'N']
# ['C' 'H' 'N']
# atom_0 ['H']
# ['H']
# bond_type ['1.0CH' 'none' '1.0HN']
# ['1.0CH' '1.0HN' 'none']
# type_1 ['JHC' 'JHH' 'JHN']
# ['JHC' 'JHH' 'JHN']
# type_0 ['1' '2' '3']
# ['1' '2' '3']
# tertiary_atom_17 [nan 'H' 'HO' 'C3' 'O3' 'O2' 'C1' 'N1' 'C2' 'Nam' 'N3' 'N2' 'Car' 'Nar'
#  'Npl' 'O.co2' 'Cac' 'N3+' 'F']
# ['C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam' 'Nar'
#  'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_7 [nan 'H' 'C3' 'O3' 'HO' 'O2' 'C1' 'N1' 'C2' 'N3' 'Car' 'Nar' 'Npl' 'Nam'
#  'N2' 'Cac' 'O.co2' 'N3+' 'C+' 'Nox' 'F' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_5 [nan 'H' 'C3' 'O3' 'O2' 'C1' 'N1' 'HO' 'N2' 'Car' 'Nar' 'N3' 'C2' 'Nam'
#  'Npl' 'N3+' 'O.co2' 'Nox' 'F' 'Cac' 'C+' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_8 [nan 'H' 'C3' 'O3' 'O2' 'HO' 'C1' 'N1' 'N3' 'Car' 'Nar' 'C2' 'Nam' 'Cac'
#  'O.co2' 'N2' 'Npl' 'Nox' 'N3+' 'F' 'Ng+' 'C+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_19 [nan 'H' 'C3' 'HO' 'O2' 'O3' 'N2' 'C1' 'N1' 'N3' 'C2' 'Nam' 'O.co2']
# ['C1' 'C2' 'C3' 'H' 'HO' 'N1' 'N2' 'N3' 'Nam' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_24 [nan 'H' 'HO' 'C3']
# ['C3' 'H' 'HO' 'nan']
# tertiary_atom_3 [nan 'H' 'C3' 'HO' 'O3' 'C1' 'N1' 'O2' 'C2' 'N3' 'N2' 'Car' 'Nam' 'Nar'
#  'Nox' 'N3+' 'Cac' 'Npl' 'F' 'C+' 'O.co2' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_18 [nan 'H' 'HO' 'C3' 'O3' 'C1' 'O2' 'C2' 'N1' 'N3' 'N2' 'Car' 'Nam' 'O.co2'
#  'Cac']
# ['C1' 'C2' 'C3' 'Cac' 'Car' 'H' 'HO' 'N1' 'N2' 'N3' 'Nam' 'O.co2' 'O2'
#  'O3' 'nan']
# tertiary_atom_1 ['H' nan 'C1' 'C3' 'O2' 'C2' 'Nam' 'O3' 'N2' 'Car' 'Nar' 'N3' 'Nox' 'Npl'
#  'N3+' 'O.co2' 'HO' 'C+' 'F' 'Cac' 'N1' 'Ng+']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_16 [nan 'H' 'C3' 'O3' 'HO' 'O2' 'O.co2' 'C1' 'N1' 'C2' 'Nam' 'N3' 'N2' 'Nox'
#  'Nar' 'Car' 'Npl' 'Cac' 'N3+' 'F']
# ['C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam' 'Nar'
#  'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_22 [nan 'H' 'C3' 'HO' 'O2' 'O3']
# ['C3' 'H' 'HO' 'O2' 'O3' 'nan']
# tertiary_atom_23 [nan 'H' 'C3' 'HO' 'O3']
# ['C3' 'H' 'HO' 'O3' 'nan']
# tertiary_atom_4 [nan 'H' 'O2' 'O3' 'C3' 'Nam' 'C1' 'HO' 'N1' 'C2' 'N2' 'Car' 'Nar' 'N3'
#  'Npl' 'N3+' 'O.co2' 'F' 'Cac' 'Nox' 'C+' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_6 [nan 'H' 'C3' 'HO' 'C1' 'N1' 'O3' 'N2' 'O2' 'C2' 'Nam' 'N3' 'Car' 'Nar'
#  'Npl' 'Cac' 'O.co2' 'Nox' 'F' 'C+' 'N3+' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# bond_atom ['C3' 'H' 'N3' 'HO' 'C1' 'N1' 'C2' 'Nam' 'N2' 'Nar' 'Car' 'Nox' 'Npl'
#  'N3+' 'Cac' 'C+' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam' 'Nar'
#  'Ng+' 'Nox' 'Npl' 'Ntr']
# tertiary_atom_9 [nan 'H' 'HO' 'O3' 'C1' 'O2' 'C3' 'C2' 'N1' 'Nam' 'O.co2' 'Cac' 'N2' 'N3'
#  'Npl' 'Car' 'Nar' 'Nox' 'N3+' 'F' 'Ng+' 'C+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_26 [nan 'H']
# ['H' 'nan']
# tertiary_atom_2 ['H' nan 'C3' 'O3' 'C1' 'C2' 'O2' 'N1' 'N3' 'Car' 'Nar' 'Nam' 'N2' 'HO'
#  'Npl' 'N3+' 'O.co2' 'Cac' 'F' 'C+' 'Nox' 'Ng+']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_15 [nan 'H' 'HO' 'C3' 'N1' 'O2' 'O3' 'C1' 'C2' 'N2' 'Nam' 'O.co2' 'N3' 'Nox'
#  'Car' 'Nar' 'Npl' 'Cac' 'N3+' 'F']
# ['C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam' 'Nar'
#  'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_14 [nan 'H' 'C3' 'O3' 'HO' 'O2' 'N1' 'C1' 'C2' 'Nam' 'N3' 'N2' 'Car' 'Nar'
#  'Cac' 'O.co2' 'Nox' 'Npl' 'F' 'N3+']
# ['C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam' 'Nar'
#  'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_12 [nan 'H' 'HO' 'C3' 'O2' 'O3' 'C1' 'N1' 'C2' 'N2' 'Nam' 'N3' 'Nox' 'Car'
#  'Npl' 'Nar' 'O.co2' 'Cac' 'N3+' 'F' 'Ng+' 'C+']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_11 [nan 'H' 'O3' 'C3' 'HO' 'N1' 'C1' 'O2' 'C2' 'Nam' 'N2' 'Car' 'Nar' 'N3'
#  'Npl' 'Nox' 'F' 'O.co2' 'Cac' 'N3+' 'Ng+' 'C+']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_13 [nan 'H' 'O2' 'HO' 'C3' 'O3' 'C1' 'C2' 'Nam' 'N1' 'N3' 'N2' 'Nox' 'Npl'
#  'Car' 'Nar' 'O.co2' 'Cac' 'N3+' 'F' 'Ng+' 'C+']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_25 [nan 'H' 'C3']
# ['C3' 'H' 'nan']
# tertiary_atom_20 [nan 'H' 'C3' 'HO' 'O3' 'O2' 'Nam' 'C2' 'C1' 'N1' 'N3']
# ['C1' 'C2' 'C3' 'H' 'HO' 'N1' 'N3' 'Nam' 'O2' 'O3' 'nan']
# tertiary_atom_21 [nan 'H' 'HO' 'C3' 'O2' 'C1' 'N1' 'O3' 'C2' 'N3']
# ['C1' 'C2' 'C3' 'H' 'HO' 'N1' 'N3' 'O2' 'O3' 'nan']
# tertiary_atom_10 [nan 'H' 'HO' 'O2' 'O3' 'C3' 'C1' 'C2' 'Nam' 'O.co2' 'N1' 'N3' 'N2' 'Npl'
#  'Car' 'Nar' 'Nox' 'F' 'N3+' 'Cac' 'C+' 'Ng+' 'Ntr']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'F' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam'
#  'Nar' 'Ng+' 'Nox' 'Npl' 'Ntr' 'O.co2' 'O2' 'O3' 'nan']
# tertiary_atom_0 ['H' 'C3' 'N3' 'O3' 'N1' 'C1' 'C2' 'O2' 'Nam' 'Car' 'Nar' 'N2' 'Nox' 'Npl'
#  'N3+' 'HO' 'C+' 'Ng+' 'Cac' 'O.co2']
# ['C+' 'C1' 'C2' 'C3' 'Cac' 'Car' 'H' 'HO' 'N1' 'N2' 'N3' 'N3+' 'Nam' 'Nar'
#  'Ng+' 'Nox' 'Npl' 'O.co2' 'O2' 'O3']
# =========================fill nan inf===============================
# =========================rename===============================
